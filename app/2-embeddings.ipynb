# %%
from datasets import load_dataset
import tiktoken

# %%
enc = tiktoken.encoding_for_model("text-embedding-3-small")

def count_tokens_for_field(field="title", streaming=True):
    ds = load_dataset("mhurhangee/cpc-classifications", split="train", streaming=streaming)
    total_tokens = 0
    total_rows = 0

    for rec in ds:
        text = rec.get(field)
        if not text:
            continue
        total_tokens += len(enc.encode(text))
        total_rows += 1

    print(f"{field}: {total_rows:,} rows, {total_tokens:,} tokens")
    return total_tokens

# %%
tokens_title = count_tokens_for_field("title")
# Out:
# title: 261,962 rows, 5,707,234 tokens

# %%
tokens_fulltitle = count_tokens_for_field("fullTitle")
# Out:
# fullTitle: 261,962 rows, 44,329,356 tokens

# %%
BATCH_COST_MILLION_TOKENS = 0.01

print(f"${BATCH_COST_MILLION_TOKENS * (tokens_title / 1_000_000):.2f}")
print(f"${BATCH_COST_MILLION_TOKENS * (tokens_fulltitle / 1_000_000):.2f}")
# Out:
# $0.06
# $0.44

# %%
from datasets import load_dataset
import json
import os

# Config
HF_DATASET = "mhurhangee/cpc-classifications"
TEXT_FIELD = "fullTitle"   # we decided to use fullTitle only
BATCH_LIMIT = 50_000       # max embedding inputs per batch
SIZE_LIMIT = 200 * 1024 * 1024  # 200MB in bytes
OUTPUT_PREFIX = "cpc_batch"

# Load dataset in streaming mode
dataset = load_dataset(HF_DATASET, split="train", streaming=True)

batch_index = 1
count_in_batch = 0
bytes_in_batch = 0
current_file = open(f"{OUTPUT_PREFIX}_{batch_index}.jsonl", "w")

def new_batch_file():
    global batch_index, count_in_batch, bytes_in_batch, current_file
    if current_file:
        current_file.close()
    batch_index += 1
    count_in_batch = 0
    bytes_in_batch = 0
    current_file = open(f"{OUTPUT_PREFIX}_{batch_index}.jsonl", "w")

for rec in dataset:
    text = rec.get(TEXT_FIELD)
    if not text:
        continue

    # Prepare line in Batch API format
    obj = {
        "custom_id": rec["key"],
        "method": "POST",
        "url": "/v1/embeddings",
        "body": {
            "model": "text-embedding-3-small",
            "input": text
        }
    }
    line = json.dumps(obj) + "\n"
    line_size = len(line.encode("utf-8"))

    # Check limits before writing
    if (count_in_batch >= BATCH_LIMIT) or (bytes_in_batch + line_size > SIZE_LIMIT):
        print(f"[INFO] Finalized batch {batch_index} with {count_in_batch} records, {bytes_in_batch/1024/1024:.2f} MB")
        new_batch_file()

    current_file.write(line)
    count_in_batch += 1
    bytes_in_batch += line_size

# Close last file
current_file.close()
print(f"[INFO] Finalized batch {batch_index} with {count_in_batch} records, {bytes_in_batch/1024/1024:.2f} MB")
# Out:
# [INFO] Finalized batch 1 with 50000 records, 42.76 MB
# [INFO] Finalized batch 2 with 50000 records, 42.59 MB
# [INFO] Finalized batch 3 with 50000 records, 43.10 MB
# [INFO] Finalized batch 4 with 50000 records, 42.98 MB
# [INFO] Finalized batch 5 with 50000 records, 42.93 MB
# [INFO] Finalized batch 6 with 11962 records, 10.24 MB

# %%
batch_ids= ["file-6PcKcuySJpJLHsY42tVCCP", "file-1RsVmLgzmt6AJoK7QJR5GR", "file-LUbsM1yDcQcFH5njenE2jQ", "file-4M21GRYfpxzFhBX8419sdK", "file-D2RhZVAEd65JzqW8Jtjbm9", "file-SpSmzE8SDyVHfQgSovoHNR"]

# %%
from openai import OpenAI
client = OpenAI()

import glob
batch_ids = []
for file in sorted(glob.glob("cpc_batch_*.jsonl")):
    batch = client.files.create(
        file=open(file, "rb"),
        purpose="batch"
    )
    batch_ids.append(batch.id)
    print(f"Created batch {batch.id} for file {file}")

# %%
upload_ids = []

for batch_id in batch_ids:
    upload = client.batches.create(
        input_file_id=batch_id,
        endpoint="/v1/embeddings",
        completion_window="24h"
    )

    upload_ids.append(upload.id)
    print(f"Created upload {upload.id} for batch {batch_id}")
# Out:
# Created upload batch_689cf8e155f48190a395a4c4d3455712 for batch file-6PcKcuySJpJLHsY42tVCCP
# Created upload batch_689cf8e2181c81909eb28b1ed55f11d6 for batch file-1RsVmLgzmt6AJoK7QJR5GR
# Created upload batch_689cf8e2cb848190a0f73198007d08b4 for batch file-LUbsM1yDcQcFH5njenE2jQ
# Created upload batch_689cf8e34a8c8190b41cfc7d7476a35b for batch file-4M21GRYfpxzFhBX8419sdK
# Created upload batch_689cf8e3a0208190abfb0b7357c09ab1 for batch file-D2RhZVAEd65JzqW8Jtjbm9
# Created upload batch_689cf8e3fad88190b5d78e883ab1b279 for batch file-SpSmzE8SDyVHfQgSovoHNR

# %%
from time import sleep
from IPython.display import clear_output

completed_ids = []

while len(completed_ids) < len(upload_ids):
    for id in upload_ids:
        batch = client.batches.retrieve(id)
        print(f"{batch.id}: {batch.status}")
        if batch.status == "completed":
            if batch.output_file_id not in completed_ids:
                completed_ids.append(batch.output_file_id)
    
    sleep(60)
    #clear output
    clear_output(wait=True)

# %%
import os
import json

import glob

jsonl_files = glob.glob("*.jsonl")


for file_id in jsonl_files:
    out_filename = f"{file_id}"
    if os.path.exists(out_filename):
        print(f"[SKIP] {out_filename} already exists")
    else:
        # Retrieve the file content from OpenAI
        resp = client.files.content(file_id)
        
        # Save locally
        with open(out_filename, "wb") as f:
            f.write(resp.read())  # resp is a stream
        
        print(f"[SAVED] Saved {out_filename}")
# Out:
# [SKIP] file-3EQSZoW9CWQL9CD2h325t3.jsonl already exists
# [SKIP] file-Cwq2kuWDg6jDy1rjs5u9va.jsonl already exists
# [SKIP] file-V6fas7QoGYVpnSMHSo8XZm.jsonl already exists
# [SKIP] file-D7T2jFJTMweWFsgLdU7Zrm.jsonl already exists
# [SKIP] file-5YcMZ6iWq63RCkjT3fA4Xv.jsonl already exists
# [SKIP] file-7WimV3F2DLUqx7SpaaGDxn.jsonl already exists

# %%
from datasets import load_dataset, Dataset
import json
import glob
import os

HF_DATASET = "mhurhangee/cpc-classifications"
HF_DATASET_EMBEDDINGS = "mhurhangee/cpc-classifications-embeddings"

# Temp working file
merged_file = "cpc_with_embeddings.jsonl"

# Remove if exists
if os.path.exists(merged_file):
    os.remove(merged_file)

# %%
# Loop over each OpenAI output file
for out_file in sorted(glob.glob("*.jsonl")):
    print(f"[INFO] Processing {out_file} ...")

    # Load embeddings from this output file into a dict
    embedding_map = {}
    with open(out_file, "r") as f:
        for line in f:
            row = json.loads(line)
            cid = row["custom_id"]
            emb = row["response"]["body"]["data"][0]["embedding"]
            embedding_map[cid] = emb

    # Stream through HF dataset and write only matching rows
    for rec in load_dataset(HF_DATASET, split="train", streaming=True):
        if rec["key"] in embedding_map:
            rec["fullTitleEmbedding"] = embedding_map[rec["key"]]
            with open(merged_file, "a") as out_f:
                out_f.write(json.dumps(rec) + "\n")

    # Clear memory for this batch
    del embedding_map

print(f"[OK] Merged dataset written to {merged_file}")
# Out:
# [INFO] Processing file-3EQSZoW9CWQL9CD2h325t3.jsonl ...
# [INFO] Processing file-5YcMZ6iWq63RCkjT3fA4Xv.jsonl ...
# [INFO] Processing file-7WimV3F2DLUqx7SpaaGDxn.jsonl ...
# [INFO] Processing file-Cwq2kuWDg6jDy1rjs5u9va.jsonl ...
# [INFO] Processing file-D7T2jFJTMweWFsgLdU7Zrm.jsonl ...
# [INFO] Processing file-V6fas7QoGYVpnSMHSo8XZm.jsonl ...
# [OK] Merged dataset written to cpc_with_embeddings.jsonl

# %%
from huggingface_hub import login
from utils.env_loader import load_project_env
import os

load_project_env()
login(token=os.getenv("HF_TOKEN"))
# Reload and push to hub
merged_ds = load_dataset("json", data_files=merged_file, split="train")
merged_ds.push_to_hub(HF_DATASET_EMBEDDINGS)
print(f"[DONE] Pushed to {HF_DATASET_EMBEDDINGS}")
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# Generating train split: 261960 examples [00:26, 9791.05 examples/s]
# Creating parquet from Arrow format: 100%|██████████| 33/33 [00:02<00:00, 12.55ba/s]
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
#
# Processing Files (0 / 1)                :   0%|          | 1.16MB /  431MB,  725kB/s
# Processing Files (0 / 1)                :   0%|          | 1.49MB /  431MB,  828kB/s
# Processing Files (0 / 1)                :   1%|          | 3.51MB /  431MB, 1.76MB/s
#
# Processing Files (0 / 1)                :   1%|▏         | 5.77MB /  431MB, 2.40MB/s
# Processing Files (0 / 1)                :   3%|▎         | 10.9MB /  431MB, 4.20MB/s
# Processing Files (0 / 1)                :   4%|▍         | 18.7MB /  431MB, 6.67MB/s
# Processing Files (0 / 1)                :   7%|▋         | 29.3MB /  431MB, 9.77MB/s
# Processing Files (0 / 1)                :  10%|▉         | 41.6MB /  431MB, 13.0MB/s
# Processing Files (0 / 1)                :  14%|█▎        | 58.9MB /  431MB, 17.3MB/s
# Processing Files (0 / 1)                :  18%|█▊        | 78.8MB /  431MB, 21.9MB/s
# Processing Files (0 / 1)                :  24%|██▍       |  103MB /  431MB, 27.2MB/s
# Processing Files (0 / 1)                :  30%|██▉       |  128MB /  431MB, 32.0MB/s
# Processing Files (0 / 1)                :  37%|███▋      |  159MB /  431MB, 38.0MB/s
# Processing Files (0 / 1)                :  44%|████▍     |  189MB /  431MB, 42.9MB/s
# Processing Files (0 / 1)                :  51%|█████▏    |  222MB /  431MB, 48.2MB/s
# Processing Files (0 / 1)                :  59%|█████▉    |  255MB /  431MB, 53.2MB/s
# Processing Files (0 / 1)                :  69%|██████▊   |  296MB /  431MB, 59.2MB/s
# Processing Files (0 / 1)                :  75%|███████▌  |  324MB /  431MB, 62.3MB/s
# Processing Files (0 / 1)                :  81%|████████  |  348MB /  431MB, 64.4MB/s
# Processing Files (0 / 1)                :  86%|████████▌ |  369MB /  431MB, 65.9MB/s
# Processing Files (0 / 1)                :  91%|█████████ |  391MB /  431MB, 67.5MB/s
# Processing Files (0 / 1)                :  95%|█████████▍|  408MB /  431MB, 68.0MB/s
# Processing Files (0 / 1)                :  98%|█████████▊|  424MB /  431MB, 68.4MB/s
# Processing Files (0 / 1)                : 100%|█████████▉|  430MB /  431MB, 67.2MB/s
#
#
# Processing Files (0 / 1)                : 100%|█████████▉|  431MB /  431MB, 61.5MB/s
# Processing Files (0 / 1)                : 100%|█████████▉|  431MB /  431MB, 59.8MB/s
# Processing Files (1 / 1)                : 100%|██████████|  431MB /  431MB, 58.2MB/s
#
#
# Processing Files (1 / 1)                : 100%|██████████|  431MB /  431MB, 55.2MB/s
# New Data Upload                         : 100%|██████████|  417MB /  417MB, 53.4MB/s
#                                         : 100%|██████████|  431MB /  431MB
# Creating parquet from Arrow format: 100%|██████████| 33/33 [00:02<00:00, 16.42ba/s]
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
#
# Processing Files (0 / 1)                :   0%|          |  526kB /  431MB,  657kB/s
# Processing Files (0 / 1)                :   1%|          | 2.63MB /  431MB, 2.63MB/s
# Processing Files (0 / 1)                :   1%|          | 5.26MB /  431MB, 4.38MB/s
# Processing Files (0 / 1)                :   3%|▎         | 11.6MB /  431MB, 8.26MB/s
# Processing Files (0 / 1)                :   5%|▌         | 21.5MB /  431MB, 13.5MB/s
# Processing Files (0 / 1)                :   8%|▊         | 32.6MB /  431MB, 18.1MB/s
# Processing Files (0 / 1)                :  11%|█         | 47.3MB /  431MB, 23.6MB/s
# Processing Files (0 / 1)                :  15%|█▌        | 66.7MB /  431MB, 30.3MB/s
# Processing Files (0 / 1)                :  19%|█▉        | 81.4MB /  431MB, 33.9MB/s
# Processing Files (0 / 1)                :  24%|██▍       |  105MB /  431MB, 40.2MB/s
# Processing Files (0 / 1)                :  30%|██▉       |  127MB /  431MB, 45.4MB/s
# Processing Files (0 / 1)                :  35%|███▌      |  152MB /  431MB, 50.8MB/s
# Processing Files (0 / 1)                :  41%|████      |  176MB /  431MB, 55.0MB/s
# Processing Files (0 / 1)                :  47%|████▋     |  201MB /  431MB, 59.2MB/s
# Processing Files (0 / 1)                :  52%|█████▏    |  225MB /  431MB, 62.4MB/s
# Processing Files (0 / 1)                :  58%|█████▊    |  249MB /  431MB, 65.5MB/s
# Processing Files (0 / 1)                :  63%|██████▎   |  271MB /  431MB, 67.7MB/s
# Processing Files (0 / 1)                :  67%|██████▋   |  291MB /  431MB, 69.2MB/s
# Processing Files (0 / 1)                :  74%|███████▎  |  317MB /  431MB, 72.1MB/s
# Processing Files (0 / 1)                :  80%|███████▉  |  344MB /  431MB, 74.8MB/s
# Processing Files (0 / 1)                :  87%|████████▋ |  376MB /  431MB, 78.2MB/s
# Processing Files (0 / 1)                :  93%|█████████▎|  400MB /  431MB, 79.9MB/s
# Processing Files (0 / 1)                :  95%|█████████▌|  411MB /  431MB, 79.0MB/s
# Processing Files (0 / 1)                :  97%|█████████▋|  419MB /  431MB, 77.6MB/s
# Processing Files (0 / 1)                :  99%|█████████▉|  426MB /  431MB, 76.2MB/s
# Processing Files (0 / 1)                : 100%|█████████▉|  430MB /  431MB, 74.1MB/s
# Processing Files (0 / 1)                : 100%|█████████▉|  431MB /  431MB, 71.8MB/s
#
#
# Processing Files (1 / 1)                : 100%|██████████|  431MB /  431MB, 65.3MB/s
#
#
# Processing Files (1 / 1)                : 100%|██████████|  431MB /  431MB, 61.5MB/s
# New Data Upload                         : 100%|██████████|  431MB /  431MB, 61.5MB/s
#                                         : 100%|██████████|  431MB /  431MB
# Creating parquet from Arrow format: 100%|██████████| 33/33 [00:02<00:00, 15.86ba/s]
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
#
# Processing Files (0 / 1)                :   0%|          |  526kB /  431MB,  658kB/s
# Processing Files (0 / 1)                :   0%|          | 2.10MB /  431MB, 2.10MB/s
# Processing Files (0 / 1)                :   1%|          | 4.73MB /  431MB, 3.95MB/s
# Processing Files (0 / 1)                :   3%|▎         | 12.1MB /  431MB, 8.64MB/s
# Processing Files (0 / 1)                :   5%|▍         | 20.0MB /  431MB, 12.5MB/s
# Processing Files (0 / 1)                :   7%|▋         | 31.6MB /  431MB, 17.5MB/s
# Processing Files (0 / 1)                :   9%|▉         | 40.5MB /  431MB, 20.3MB/s
# Processing Files (0 / 1)                :  13%|█▎        | 55.8MB /  431MB, 25.3MB/s
# Processing Files (0 / 1)                :  17%|█▋        | 71.5MB /  431MB, 29.8MB/s
# Processing Files (0 / 1)                :  21%|██        | 90.5MB /  431MB, 34.8MB/s
# Processing Files (0 / 1)                :  26%|██▌       |  111MB /  431MB, 39.6MB/s
# Processing Files (0 / 1)                :  30%|███       |  131MB /  431MB, 43.7MB/s
# Processing Files (0 / 1)                :  35%|███▌      |  151MB /  431MB, 47.2MB/s
# Processing Files (0 / 1)                :  40%|████      |  174MB /  431MB, 51.1MB/s
# Processing Files (0 / 1)                :  46%|████▌     |  196MB /  431MB, 54.5MB/s
# Processing Files (0 / 1)                :  50%|█████     |  216MB /  431MB, 56.9MB/s
# Processing Files (0 / 1)                :  56%|█████▌    |  242MB /  431MB, 60.4MB/s
# Processing Files (0 / 1)                :  63%|██████▎   |  271MB /  431MB, 64.4MB/s
# Processing Files (0 / 1)                :  70%|██████▉   |  300MB /  431MB, 68.3MB/s
# Processing Files (0 / 1)                :  77%|███████▋  |  331MB /  431MB, 72.0MB/s
# Processing Files (0 / 1)                :  83%|████████▎ |  360MB /  431MB, 74.9MB/s
# Processing Files (0 / 1)                :  88%|████████▊ |  380MB /  431MB, 76.0MB/s
# Processing Files (0 / 1)                :  91%|█████████ |  392MB /  431MB, 75.4MB/s
# Processing Files (0 / 1)                :  94%|█████████▍|  404MB /  431MB, 74.9MB/s
# Processing Files (0 / 1)                :  98%|█████████▊|  420MB /  431MB, 75.0MB/s
# Processing Files (0 / 1)                : 100%|█████████▉|  429MB /  431MB, 73.9MB/s
# Processing Files (0 / 1)                : 100%|█████████▉|  430MB /  431MB, 71.7MB/s
#
#
# Processing Files (1 / 1)                : 100%|██████████|  431MB /  431MB, 65.2MB/s
#
#
# Processing Files (1 / 1)                : 100%|██████████|  431MB /  431MB, 61.5MB/s
# New Data Upload                         : 100%|██████████|  431MB /  431MB, 61.5MB/s
#                                         : 100%|██████████|  431MB /  431MB
# Creating parquet from Arrow format: 100%|██████████| 33/33 [00:02<00:00, 13.58ba/s]
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
#
# Processing Files (0 / 1)                :   0%|          |  526kB /  431MB,  657kB/s
# Processing Files (0 / 1)                :   0%|          | 2.10MB /  431MB, 2.10MB/s
# Processing Files (0 / 1)                :   1%|          | 4.73MB /  431MB, 3.94MB/s
# Processing Files (0 / 1)                :   2%|▏         | 10.5MB /  431MB, 7.51MB/s
# Processing Files (0 / 1)                :   4%|▍         | 18.9MB /  431MB, 11.8MB/s
# Processing Files (0 / 1)                :   7%|▋         | 29.4MB /  431MB, 16.4MB/s
# Processing Files (0 / 1)                :   9%|▉         | 39.4MB /  431MB, 19.7MB/s
# Processing Files (0 / 1)                :  12%|█▏        | 53.1MB /  431MB, 24.1MB/s
# Processing Files (0 / 1)                :  16%|█▋        | 70.5MB /  431MB, 29.4MB/s
# Processing Files (0 / 1)                :  21%|██        | 89.4MB /  431MB, 34.4MB/s
# Processing Files (0 / 1)                :  25%|██▌       |  109MB /  431MB, 38.9MB/s
# Processing Files (0 / 1)                :  29%|██▉       |  126MB /  431MB, 42.1MB/s
# Processing Files (0 / 1)                :  32%|███▏      |  140MB /  431MB, 43.7MB/s
# Processing Files (0 / 1)                :  36%|███▋      |  157MB /  431MB, 46.1MB/s
# Processing Files (0 / 1)                :  40%|████      |  174MB /  431MB, 48.4MB/s
# Processing Files (0 / 1)                :  44%|████▎     |  188MB /  431MB, 49.6MB/s
# Processing Files (0 / 1)                :  47%|████▋     |  203MB /  431MB, 50.8MB/s
# Processing Files (0 / 1)                :  52%|█████▏    |  225MB /  431MB, 53.6MB/s
# Processing Files (0 / 1)                :  57%|█████▋    |  244MB /  431MB, 55.5MB/s
# Processing Files (0 / 1)                :  62%|██████▏   |  267MB /  431MB, 58.1MB/s
# Processing Files (0 / 1)                :  69%|██████▊   |  295MB /  431MB, 61.5MB/s
# Processing Files (0 / 1)                :  75%|███████▍  |  323MB /  431MB, 64.5MB/s
# Processing Files (0 / 1)                :  82%|████████▏ |  354MB /  431MB, 68.1MB/s
# Processing Files (0 / 1)                :  87%|████████▋ |  375MB /  431MB, 69.5MB/s
# Processing Files (0 / 1)                :  91%|█████████▏|  394MB /  431MB, 70.3MB/s
# Processing Files (0 / 1)                :  94%|█████████▎|  404MB /  431MB, 69.6MB/s
# Processing Files (0 / 1)                :  95%|█████████▌|  411MB /  431MB, 68.5MB/s
# Processing Files (0 / 1)                :  97%|█████████▋|  419MB /  431MB, 67.6MB/s
# Processing Files (0 / 1)                :  99%|█████████▉|  427MB /  431MB, 66.8MB/s
# Processing Files (0 / 1)                : 100%|█████████▉|  430MB /  431MB, 65.2MB/s
# Processing Files (0 / 1)                : 100%|█████████▉|  430MB /  431MB, 63.3MB/s
#
#
# Processing Files (1 / 1)                : 100%|██████████|  431MB /  431MB, 58.2MB/s
#
#
#
# Processing Files (1 / 1)                : 100%|██████████|  431MB /  431MB, 53.9MB/s
# New Data Upload                         : 100%|██████████|  431MB /  431MB, 53.9MB/s
#                                         : 100%|██████████|  431MB /  431MB
# Creating parquet from Arrow format: 100%|██████████| 33/33 [00:02<00:00, 12.92ba/s]
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
#
# Processing Files (0 / 1)                :   0%|          |  526kB /  431MB,  657kB/s
# Processing Files (0 / 1)                :   0%|          | 1.05MB /  431MB, 1.05MB/s
# Processing Files (0 / 1)                :   1%|          | 5.26MB /  431MB, 4.38MB/s
# Processing Files (0 / 1)                :   2%|▏         | 8.41MB /  431MB, 6.01MB/s
# Processing Files (0 / 1)                :   4%|▍         | 18.4MB /  431MB, 11.5MB/s
# Processing Files (0 / 1)                :   7%|▋         | 31.0MB /  431MB, 17.2MB/s
# Processing Files (0 / 1)                :  11%|█         | 48.4MB /  431MB, 24.2MB/s
# Processing Files (0 / 1)                :  16%|█▌        | 66.8MB /  431MB, 30.4MB/s
# Processing Files (0 / 1)                :  21%|██▏       | 92.6MB /  431MB, 38.6MB/s
# Processing Files (0 / 1)                :  28%|██▊       |  120MB /  431MB, 46.3MB/s
# Processing Files (0 / 1)                :  35%|███▍      |  149MB /  431MB, 53.3MB/s
# Processing Files (0 / 1)                :  42%|████▏     |  180MB /  431MB, 60.0MB/s
# Processing Files (0 / 1)                :  47%|████▋     |  203MB /  431MB, 63.3MB/s
# Processing Files (0 / 1)                :  53%|█████▎    |  227MB /  431MB, 66.8MB/s
# Processing Files (0 / 1)                :  58%|█████▊    |  249MB /  431MB, 69.3MB/s
# Processing Files (0 / 1)                :  64%|██████▍   |  275MB /  431MB, 72.3MB/s
# Processing Files (0 / 1)                :  68%|██████▊   |  295MB /  431MB, 73.7MB/s
# Processing Files (0 / 1)                :  73%|███████▎  |  315MB /  431MB, 75.1MB/s
# Processing Files (0 / 1)                :  77%|███████▋  |  331MB /  431MB, 75.2MB/s
# Processing Files (0 / 1)                :  82%|████████▏ |  353MB /  431MB, 76.7MB/s
# Processing Files (0 / 1)                :  87%|████████▋ |  374MB /  431MB, 77.9MB/s
# Processing Files (0 / 1)                :  91%|█████████▏|  394MB /  431MB, 78.8MB/s
# Processing Files (0 / 1)                :  94%|█████████▍|  407MB /  431MB, 78.3MB/s
# Processing Files (0 / 1)                :  96%|█████████▌|  414MB /  431MB, 76.7MB/s
# Processing Files (0 / 1)                :  97%|█████████▋|  418MB /  431MB, 74.7MB/s
# Processing Files (0 / 1)                :  99%|█████████▊|  425MB /  431MB, 73.3MB/s
# Processing Files (0 / 1)                : 100%|█████████▉|  430MB /  431MB, 71.7MB/s
# Processing Files (0 / 1)                : 100%|█████████▉|  430MB /  431MB, 69.4MB/s
#
#
# Processing Files (1 / 1)                : 100%|██████████|  431MB /  431MB, 63.4MB/s
#
#
# Processing Files (1 / 1)                : 100%|██████████|  431MB /  431MB, 59.8MB/s
# New Data Upload                         : 100%|██████████|  431MB /  431MB, 59.8MB/s
#                                         : 100%|██████████|  431MB /  431MB
# Creating parquet from Arrow format: 100%|██████████| 33/33 [00:02<00:00, 12.61ba/s]
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
#
# Processing Files (0 / 1)                :   0%|          |  525kB /  431MB,  655kB/s
# Processing Files (0 / 1)                :   0%|          | 1.05MB /  431MB, 1.05MB/s
# Processing Files (0 / 1)                :   1%|          | 4.73MB /  431MB, 3.94MB/s
# Processing Files (0 / 1)                :   2%|▏         | 7.87MB /  431MB, 5.62MB/s
# Processing Files (0 / 1)                :   4%|▍         | 18.9MB /  431MB, 11.8MB/s
# Processing Files (0 / 1)                :   6%|▌         | 26.8MB /  431MB, 14.9MB/s
# Processing Files (0 / 1)                :  10%|█         | 43.6MB /  431MB, 21.8MB/s
# Processing Files (0 / 1)                :  14%|█▍        | 62.0MB /  431MB, 28.2MB/s
# Processing Files (0 / 1)                :  20%|█▉        | 85.6MB /  431MB, 35.7MB/s
# Processing Files (0 / 1)                :  25%|██▌       |  109MB /  431MB, 42.0MB/s
# Processing Files (0 / 1)                :  31%|███       |  134MB /  431MB, 48.0MB/s
# Processing Files (0 / 1)                :  37%|███▋      |  159MB /  431MB, 52.9MB/s
# Processing Files (0 / 1)                :  42%|████▏     |  181MB /  431MB, 56.6MB/s
# Processing Files (0 / 1)                :  48%|████▊     |  207MB /  431MB, 60.9MB/s
# Processing Files (0 / 1)                :  53%|█████▎    |  227MB /  431MB, 63.2MB/s
# Processing Files (0 / 1)                :  57%|█████▋    |  245MB /  431MB, 64.5MB/s
# Processing Files (0 / 1)                :  61%|██████    |  262MB /  431MB, 65.6MB/s
# Processing Files (0 / 1)                :  65%|██████▌   |  282MB /  431MB, 67.1MB/s
# Processing Files (0 / 1)                :  71%|███████   |  304MB /  431MB, 69.1MB/s
# Processing Files (0 / 1)                :  76%|███████▋  |  329MB /  431MB, 71.6MB/s
# Processing Files (0 / 1)                :  82%|████████▏ |  351MB /  431MB, 73.2MB/s
# Processing Files (0 / 1)                :  87%|████████▋ |  375MB /  431MB, 75.1MB/s
# Processing Files (0 / 1)                :  92%|█████████▏|  396MB /  431MB, 76.1MB/s
# Processing Files (0 / 1)                :  95%|█████████▍|  408MB /  431MB, 75.6MB/s
# Processing Files (0 / 1)                :  97%|█████████▋|  417MB /  431MB, 74.4MB/s
# Processing Files (0 / 1)                :  99%|█████████▊|  425MB /  431MB, 73.2MB/s
# Processing Files (0 / 1)                : 100%|█████████▉|  430MB /  431MB, 71.6MB/s
# Processing Files (0 / 1)                : 100%|█████████▉|  430MB /  431MB, 69.4MB/s
#
#
#
# Processing Files (1 / 1)                : 100%|██████████|  431MB /  431MB, 61.5MB/s
#
#
# Processing Files (1 / 1)                : 100%|██████████|  431MB /  431MB, 58.2MB/s
# New Data Upload                         : 100%|██████████|  431MB /  431MB, 58.2MB/s
#                                         : 100%|██████████|  431MB /  431MB
# Creating parquet from Arrow format: 100%|██████████| 33/33 [00:02<00:00, 12.92ba/s]
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
#
# Processing Files (0 / 1)                :   0%|          |  525kB /  431MB,  875kB/s
#
# Processing Files (0 / 1)                :   0%|          | 1.05MB /  431MB, 1.05MB/s
# Processing Files (0 / 1)                :   1%|          | 2.63MB /  431MB, 2.19MB/s
# Processing Files (0 / 1)                :   1%|          | 4.20MB /  431MB, 3.00MB/s
# Processing Files (0 / 1)                :   1%|          | 5.25MB /  431MB, 3.28MB/s
# Processing Files (0 / 1)                :   2%|▏         | 7.35MB /  431MB, 4.09MB/s
# Processing Files (0 / 1)                :   3%|▎         | 11.0MB /  431MB, 5.52MB/s
# Processing Files (0 / 1)                :   5%|▌         | 22.1MB /  431MB, 10.0MB/s
# Processing Files (0 / 1)                :   8%|▊         | 34.7MB /  431MB, 14.5MB/s
# Processing Files (0 / 1)                :  13%|█▎        | 54.7MB /  431MB, 21.0MB/s
# Processing Files (0 / 1)                :  18%|█▊        | 76.7MB /  431MB, 27.4MB/s
# Processing Files (0 / 1)                :  23%|██▎       | 97.8MB /  431MB, 32.6MB/s
# Processing Files (0 / 1)                :  27%|██▋       |  116MB /  431MB, 36.1MB/s
# Processing Files (0 / 1)                :  33%|███▎      |  142MB /  431MB, 41.9MB/s
# Processing Files (0 / 1)                :  41%|████▏     |  178MB /  431MB, 49.5MB/s
# Processing Files (0 / 1)                :  50%|████▉     |  214MB /  431MB, 56.3MB/s
# Processing Files (0 / 1)                :  59%|█████▊    |  253MB /  431MB, 63.2MB/s
# Processing Files (0 / 1)                :  67%|██████▋   |  290MB /  431MB, 69.0MB/s
# Processing Files (0 / 1)                :  75%|███████▌  |  324MB /  431MB, 73.7MB/s
# Processing Files (0 / 1)                :  83%|████████▎ |  358MB /  431MB, 77.7MB/s
# Processing Files (0 / 1)                :  89%|████████▉ |  384MB /  431MB, 80.1MB/s
# Processing Files (0 / 1)                :  94%|█████████▍|  404MB /  431MB, 80.8MB/s
# Processing Files (0 / 1)                :  98%|█████████▊|  421MB /  431MB, 80.9MB/s
# Processing Files (0 / 1)                : 100%|█████████▉|  429MB /  431MB, 79.4MB/s
# Processing Files (0 / 1)                : 100%|█████████▉|  429MB /  431MB, 76.6MB/s
#
# Processing Files (0 / 1)                : 100%|█████████▉|  430MB /  431MB, 71.6MB/s
# Processing Files (0 / 1)                : 100%|█████████▉|  430MB /  431MB, 69.4MB/s
#
# Processing Files (1 / 1)                : 100%|██████████|  431MB /  431MB, 65.3MB/s
#
#
# Processing Files (1 / 1)                : 100%|██████████|  431MB /  431MB, 61.5MB/s
# New Data Upload                         : 100%|██████████|  431MB /  431MB, 61.5MB/s
#                                         : 100%|██████████|  431MB /  431MB
# Creating parquet from Arrow format: 100%|██████████| 33/33 [00:02<00:00, 12.05ba/s]
# Processing Files (0 / 0)                : |          |  0.00B /  0.00B
#
# Processing Files (0 / 1)                :   0%|          |  527kB /  431MB,  659kB/s
# Processing Files (0 / 1)                :   0%|          | 1.05MB /  431MB, 1.05MB/s
# Processing Files (0 / 1)                :   1%|          | 3.69MB /  431MB, 3.08MB/s
# Processing Files (0 / 1)                :   2%|▏         | 7.91MB /  431MB, 5.65MB/s
# Processing Files (0 / 1)                :   3%|▎         | 14.8MB /  431MB, 9.23MB/s
# Processing Files (0 / 1)                :   6%|▌         | 25.8MB /  431MB, 14.4MB/s
# Processing Files (0 / 1)                :  10%|▉         | 41.7MB /  431MB, 20.8MB/s
# Processing Files (0 / 1)                :  14%|█▍        | 61.7MB /  431MB, 28.0MB/s
# Processing Files (0 / 1)                :  19%|█▉        | 82.8MB /  431MB, 34.5MB/s
# Processing Files (0 / 1)                :  25%|██▍       |  108MB /  431MB, 41.4MB/s
# Processing Files (0 / 1)                :  31%|███       |  133MB /  431MB, 47.6MB/s
# Processing Files (0 / 1)                :  36%|███▋      |  157MB /  431MB, 52.4MB/s
# Processing Files (0 / 1)                :  42%|████▏     |  179MB /  431MB, 56.0MB/s
# Processing Files (0 / 1)                :  46%|████▌     |  198MB /  431MB, 58.1MB/s
# Processing Files (0 / 1)                :  49%|████▉     |  213MB /  431MB, 59.1MB/s
# Processing Files (0 / 1)                :  54%|█████▍    |  232MB /  431MB, 61.2MB/s
# Processing Files (0 / 1)                :  58%|█████▊    |  249MB /  431MB, 62.3MB/s
# Processing Files (0 / 1)                :  64%|██████▍   |  276MB /  431MB, 65.6MB/s
# Processing Files (0 / 1)                :  71%|███████▏  |  307MB /  431MB, 69.8MB/s
# Processing Files (0 / 1)                :  78%|███████▊  |  337MB /  431MB, 73.3MB/s
# Processing Files (0 / 1)                :  84%|████████▍ |  363MB /  431MB, 75.5MB/s
# Processing Files (0 / 1)                :  88%|████████▊ |  379MB /  431MB, 75.9MB/s
# Processing Files (0 / 1)                :  92%|█████████▏|  396MB /  431MB, 76.1MB/s
# Processing Files (0 / 1)                :  96%|█████████▌|  412MB /  431MB, 76.3MB/s
# Processing Files (0 / 1)                :  99%|█████████▉|  427MB /  431MB, 76.3MB/s
# Processing Files (0 / 1)                : 100%|█████████▉|  430MB /  431MB, 74.2MB/s
#
#
# Processing Files (0 / 1)                : 100%|█████████▉|  430MB /  431MB, 67.3MB/s
# Processing Files (1 / 1)                : 100%|██████████|  431MB /  431MB, 65.3MB/s
#
#
# Processing Files (1 / 1)                : 100%|██████████|  431MB /  431MB, 61.5MB/s
# New Data Upload                         : 100%|██████████|  431MB /  431MB, 61.5MB/s
#                                         : 100%|██████████|  431MB /  431MB
# Uploading the dataset shards: 100%|██████████| 8/8 [02:22<00:00, 17.85s/ shards]
# [DONE] Pushed to mhurhangee/cpc-classifications-embeddings
